# %%
import tweepy

# API v2 Bearer Token
BEARER_TOKEN = 'ALaWwAEAAAAA01%2FOkhZMVvWxXuXN1LLUCNAME8o%3DgNzWcIDjLPrsVOFGkOKesISG3KENaAwK4m0uGM1OB5rAMVfW4j'

# Authenticate to Twitter using the API v2 Client
client = tweepy.Client(bearer_token=BEARER_TOKEN)

# Get recent tweets using API v2 (search_recent_tweets)
query = "diabetes"
response = client.search_recent_tweets(query=query, tweet_fields=['context_annotations', 'created_at'], max_results=10)

# Display fetched tweets
if response.data:
    for tweet in response.data:
        print(tweet.text)
else:
    print("No tweets found.")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 import tweepy
#       3 # API v2 Bearer Token
#       4 BEARER_TOKEN = 'ALaWwAEAAAAA01%2FOkhZMVvWxXuXN1LLUCNAME8o%3DgNzWcIDjLPrsVOFGkOKesISG3KENaAwK4m0uGM1OB5rAMVfW4j'
#
# ModuleNotFoundError: No module named 'tweepy'

# %%
import re
import tweepy
from tweepy import OAuthHandler
from textblob import TextBlob

class TwitterClient(object):
    '''
    Generic Twitter Class for sentiment analysis.
    '''
    def __init__(self):
        '''
        Class constructor or initialization method.
        '''
        # keys and tokens from the Twitter Dev Console
        consumer_key = 'XXXXXXXXXXXXXXXXXXXXXXXX'
        consumer_secret = 'XXXXXXXXXXXXXXXXXXXXXXXXXXXX'
        access_token = 'XXXXXXXXXXXXXXXXXXXXXXXXXXXX'
        access_token_secret = 'XXXXXXXXXXXXXXXXXXXXXXXXX'

        # attempt authentication
        try:
            # create OAuthHandler object
            self.auth = OAuthHandler(consumer_key, consumer_secret)
            # set access token and secret
            self.auth.set_access_token(access_token, access_token_secret)
            # create tweepy API object to fetch tweets
            self.api = tweepy.API(self.auth)
        except:
            print(&quot;Error: Authentication Failed&quot;)

    def clean_tweet(self, tweet):
        '''
        Utility function to clean tweet text by removing links, special characters
        using simple regex statements.
        '''
        return ' '.join(re.sub(&quot;(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])
                                    |(\w+:\/\/\S+)&quot;, &quot; &quot;, tweet).split())

    def get_tweet_sentiment(self, tweet):
        '''
        Utility function to classify sentiment of passed tweet
        using textblob's sentiment method
        '''
        # create TextBlob object of passed tweet text
        analysis = TextBlob(self.clean_tweet(tweet))
        # set sentiment
        if analysis.sentiment.polarity &gt; 0:
            return 'positive'
        elif analysis.sentiment.polarity == 0:
            return 'neutral'
        else:
            return 'negative'

    def get_tweets(self, query, count = 10):
        '''
        Main function to fetch tweets and parse them.
        '''
        # empty list to store parsed tweets
        tweets = []

        try:
            # call twitter api to fetch tweets
            fetched_tweets = self.api.search(q = query, count = count)

            # parsing tweets one by one
            for tweet in fetched_tweets:
                # empty dictionary to store required params of a tweet
                parsed_tweet = {}

                # saving text of tweet
                parsed_tweet['text'] = tweet.text
                # saving sentiment of tweet
                parsed_tweet['sentiment'] = self.get_tweet_sentiment(tweet.text)

                # appending parsed tweet to tweets list
                if tweet.retweet_count &gt; 0:
                    # if tweet has retweets, ensure that it is appended only once
                    if parsed_tweet not in tweets:
                        tweets.append(parsed_tweet)
                else:
                    tweets.append(parsed_tweet)

            # return parsed tweets
            return tweets

        except tweepy.TweepError as e:
            # print error (if any)
            print(&quot;Error : &quot; + str(e))

def main():
    # creating object of TwitterClient Class
    api = TwitterClient()
    # calling function to get tweets
    tweets = api.get_tweets(query = 'Donald Trump', count = 200)

    # picking positive tweets from tweets
    ptweets = [tweet for tweet in tweets if tweet['sentiment'] == 'positive']
    # percentage of positive tweets
    print(&quot;Positive tweets percentage: {} %&quot;.format(100*len(ptweets)/len(tweets)))
    # picking negative tweets from tweets
    ntweets = [tweet for tweet in tweets if tweet['sentiment'] == 'negative']
    # percentage of negative tweets
    print(&quot;Negative tweets percentage: {} %&quot;.format(100*len(ntweets)/len(tweets)))
    # percentage of neutral tweets
    print(&quot;Neutral tweets percentage: {} % \
        &quot;.format(100*(len(tweets) -(len( ntweets )+len( ptweets)))/len(tweets)))

    # printing first 5 positive tweets
    print(&quot;\n\nPositive tweets:&quot;)
    for tweet in ptweets[:10]:
        print(tweet['text'])

    # printing first 5 negative tweets
    print(&quot;\n\nNegative tweets:&quot;)
    for tweet in ntweets[:10]:
        print(tweet['text'])

if __name__ == &quot;__main__&quot;:
    # calling main function
    main()
# Out:
#   File "/tmp/ipython-input-3044395326.py", line 36
#     return ' '.join(re.sub(&quot;(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])
#                                                       ^
# SyntaxError: invalid decimal literal

# %%
pip install snscrape pandas
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.8/74.8 kB 457.4 kB/s eta 0:00:00
# ...

# %%
import pandas as pd, subprocess, json, datetime as dt

query = '("mobile\'s" OR Mobile) lang:en since:2025-06-01 until:2025-08-31'
cmd = ["snscrape", "--jsonl", "twitter-search", query]

rows = []
p = subprocess.Popen(cmd, stdout=subprocess.PIPE, text=True)
for line in p.stdout:
    t = json.loads(line)
    rows.append({
        "id": t["id"],
        "date": t["date"],
        "user": t["user"]["username"],
        "text": t["rawContent"],
        "likeCount": t["likeCount"],
        "retweetCount": t["retweetCount"],
        "replyCount": t["replyCount"],
        "lang": t["lang"],
        "url": t["url"]
    })

df = pd.DataFrame(rows)
df.to_csv("tweets_snscrape.csv", index=False)
print(f"Saved {len(df)} rows -> tweets_snscrape.csv")
# Out:
# Saved 0 rows -> tweets_snscrape.csv

# %%
import pandas as pd, subprocess, json
user = "WHO"
cmd = ["snscrape", "--jsonl", "twitter-user", user]
rows = []
p = subprocess.Popen(cmd, stdout=subprocess.PIPE, text=True)
for line in p.stdout:
    t = json.loads(line)
    rows.append({"id": t["id"], "date": t["date"], "text": t["rawContent"]})
pd.DataFrame(rows).to_csv("timeline_WHO.csv", index=False)

# %%
pip install --upgrade snscrape

# %%
import pandas as pd, subprocess, json

user = "mallinishanth72@gmail.com"
cmd = ["snscrape", "--jsonl", f"twitter-user {user}"]

rows = []
p = subprocess.Popen(" ".join(cmd), shell=True, stdout=subprocess.PIPE, text=True)

for line in p.stdout:
    t = json.loads(line)
    rows.append({
        "id": t["id"],
        "date": t["date"],
        "text": t["rawContent"]
    })

df = pd.DataFrame(rows)
df.to_csv("timeline_WHO.csv", index=False)
print(f"Saved {len(df)} tweets to timeline_WHO.csv")
# Out:
# Saved 0 tweets to timeline_WHO.csv

# %%
pip install -U snscrape pandas
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.2/91.2 kB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 105.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.3.2 which is incompatible.
# dask-cudf-cu12 25.6.0 requires pandas<2.2.4dev0,>=2.0, but you have pandas 2.3.2 which is incompatible.
# cudf-cu12 25.6.0 requires pandas<2.2.4dev0,>=2.0, but you have pandas 2.3.2 which is incompatible.
# ...

# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd

user = "WHO"
limit = 1000  # set how many tweets you want

tweets = []
for i, tweet in enumerate(sntwitter.TwitterUserScraper(user).get_items()):
    tweets.append({
        "id": tweet.id,
        "date": tweet.date,
        "username": tweet.user.username,
        "displayname": tweet.user.displayname,
        "text": tweet.rawContent,
        "replyCount": tweet.replyCount,
        "retweetCount": tweet.retweetCount,
        "likeCount": tweet.likeCount,
        "lang": tweet.lang,
        "url": tweet.url
    })
    if i + 1 >= limit:
        break

df = pd.DataFrame(tweets)
df.to_csv("timeline_WHO.csv", index=False, encoding="utf-8")
print(f"Saved {len(df)} tweets to timeline_WHO.csv")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-596477891.py in <cell line: 0>()
# ----> 1 import snscrape.modules.twitter as sntwitter
#       2 import pandas as pd
#       3
#       4 user = "WHO"
#       5 limit = 1000  # set how many tweets you want
#
# /usr/local/lib/python3.12/dist-packages/snscrape/modules/__init__.py in <module>
#      15
#      16
# ---> 17 _import_modules()
#
# /usr/local/lib/python3.12/dist-packages/snscrape/modules/__init__.py in _import_modules()
#      11                 moduleNameWithoutPrefix = moduleName[prefixLen:]
#      12                 __all__.append(moduleNameWithoutPrefix)
# ---> 13                 module = importer.find_module(moduleName).load_module(moduleName)
#      14                 globals()[moduleNameWithoutPrefix] = module
#      15
#
# AttributeError: 'FileFinder' object has no attribute 'find_module'
